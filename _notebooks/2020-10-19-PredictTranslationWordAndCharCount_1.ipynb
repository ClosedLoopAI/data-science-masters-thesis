# %% [markdown]
# # "Predict Translation Word And Char Count (Part 1)"
#
# > Prediction of translated Word or Char Count is used as a Quality or Validation Check
# - toc: true
# - branch: master
# - badges: false
# - comments: true
# - hide: false
# - search_exclude: true
# - metadata_key1: metadata_value1
# - metadata_key2: metadata_value2
# - image: images/PredictTranslationWordAndCharCount_1.png
# - categories: [Deep Learning,Regression,   Python,fastai]
# - show_tags: true

# %%
#hide
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
# base_dir = root_dir + 'TODANALYTICS/PredictTranslationWordAndCharCount'
base_dir = root_dir + 'TODANALYTICS/'
# base_dir = ""
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Purpose
# Machine translation is used increasingly to lighten the load of human translators. The critical component here is the *translation engine* which is a model that takes a sequence of source words and outputs another sequence of translated words. To train such a model many thousands of sentence pairs need to be aligned for training examples.
#
# There is a relationship between the number of words (and the number of characters) in the source language and the target language. If this relationship can be established and captured in yet another model, such a model can be helpful in at least two ways:
#
# * For training: Validate the alignment of two sentences (in a training example) by comparing their *word size* and/or *character size*
# * For inference: Validate the *word size* and/or *character size* of a translated/proofread sentence
#
# The purpose of this project is to discover such a model for a variety of languages and to evaluate its use in the above roles.

# %% [markdown]
# ## Dataset and Variables
# The dataset comes in the form of *contributions*, each captures in one of 167289 rows or data-points. Each contribution is a sentence that could be in the source language (always English) or a translation of the source sentence. There could be many variations/versions of a translated sentence, including the version provided by the translation engine initially. Human proofreaders then provide their own corrections in the form of other versions.
#
# There are 4 kinds of contributions:
#
# * E: English contributions
# * T: Translate contributions - provided by the translation engine
# * C: Create contributions - corrections provided by human proofreaders/translators
# * V: Vote contributions - whenever a human proofreader/translator indicates agreement with a contribution provided by the translation engine, it is recorded in the form of a vote contribution
#
# The features of the dataset are:
#
# * m_descriptor: Unique identifier of a document
# * t_lan: Language of the translation (English is also considered a translation)
# * t_senc: Number of sentences in a document
# * t_version: Version of a translation
# * s_typ: Type of the sentence
# * s_rsen: Number of a sentence within a document
# * e_id: Database primary key of a contribution's content
# * e_top: Content of the contribution that got the most votes
# * be_id: N/A
# * be_top: N/A
# * c_id: Database primary key of a contribution
# * c_created_at: Creation time of a contribution
# * c_kind: Kind of a contribution
# * c_eis: N/A
# * c_base: N/A
# * a_role: N/A
# * u_name: N/A
# * e_content: Text content of a contribution
# * chars: Number of characters in a contribution
# * words: Number of words in a contribution
#
# In this notebook we will only prepare the dataset. Exploratory data analysis as well as modeling will occur in followup notebooks.

# %% [markdown]
# # Setup the Environment

# %%
# 
# # ! pip install fastai
# ! pip install fastai2
# ! pip install nbdev

# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
#      |████████████████████████████████| 727kB 4.4MB/s
#      |████████████████████████████████| 194kB 14.0MB/s
#      |████████████████████████████████| 51kB 8.2MB/s
#      |████████████████████████████████| 1.0MB 19.9MB/s
#      |████████████████████████████████| 51kB 8.3MB/s
#      |████████████████████████████████| 51kB 8.8MB/s
#      |████████████████████████████████| 40kB 7.1MB/s
#      |████████████████████████████████| 92kB 11.4MB/s
#      |████████████████████████████████| 61kB 9.5MB/s
#      |████████████████████████████████| 51kB 9.2MB/s
#      |████████████████████████████████| 2.6MB 35.8MB/s

# %%
# 
# ! pip list | grep fastai
! pip list | grep fastai2

# %%
from fastai.tabular.all import *
from fastbook import *

# from fastai.tabular.all import *
# # from fastai2.tabular.all import *

# %%
import seaborn as sns
# %matplotlib inline

# %%
# !python --version
# Out:
# Python 3.6.9

# %%
# 
PATH = Path(base_dir); #PATH

# %% [markdown]
# # Get train/valid data
#
# Next we will ingest all the data we need. Note that the content (e_content) for each contribution is not displayed as it often makes the presentation unwieldy.

# %%
#hide
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %% [markdown]
# ## Ingest all E-contributions

# %%
#hide
# df_E = pd.read_csv(f'{PATH}/contributions/1955-0807y_Pride_ENG_15-0401-b_E-contributions.csv', sep='~')
# df_E = pd.read_csv(f'{PATH}/contributions/1965-0829_SatansEden_ENG_15-1104-b_E-contributions.csv', sep='~')
# df_E

# %%
all_files = glob.glob(f"{PATH}/contributions/*E-contributions.csv")
li = []
for filename in all_files:
    dft = pd.read_csv(filename, index_col=None, header=0, sep='~')
    li.append(dft)
df_E = pd.concat(li, axis=0, ignore_index=True)
df_E.iloc[:5,:-2]
# Out:
#   m_descriptor t_lan  t_senc    t_version s_typ  s_rsen    e_id e_top  be_id  \
# 0   1965-0418x   ENG    1870  18-0101-E1R     n       1  174684     Z    NaN
# 1   1965-0418x   ENG    1870  18-0101-E1R     n       2  174685     Z    NaN
# 2   1965-0418x   ENG    1870  18-0101-E1R     n       3  174686     Z    NaN
# 3   1965-0418x   ENG    1870  18-0101-E1R     n       4  174687     Z    NaN
# 4   1965-0418x   ENG    1870  18-0101-E1R     n       5  174688     Z    NaN
#
#    be_top    c_id                c_created_at c_kind  c_eis  c_base a_role
# 0     NaN  224461  2018-03-29 23:10:24.573038      E      0     NaN     EP
# 1     NaN  224462  2018-03-29 23:10:24.595501      E      0     NaN     EP
# 2     NaN  224463  2018-03-29 23:10:24.628362      E      0     NaN     EP
# 3     NaN  224464  2018-03-29 23:10:24.650119      E      0     NaN     EP
# 4     NaN  224465  2018-03-29 23:10:24.670806      E      0     NaN     EP

# %%
#hide
df_E
# Out:
#        m_descriptor t_lan  t_senc    t_version s_typ  s_rsen    e_id e_top  \
# 0        1965-0418x   ENG    1870  18-0101-E1R     n       1  174684     Z
# 1        1965-0418x   ENG    1870  18-0101-E1R     n       2  174685     Z
# 2        1965-0418x   ENG    1870  18-0101-E1R     n       3  174686     Z
# 3        1965-0418x   ENG    1870  18-0101-E1R     n       4  174687     Z
# 4        1965-0418x   ENG    1870  18-0101-E1R     n       5  174688     Z
# ...             ...   ...     ...          ...   ...     ...     ...   ...
# 167284       CAB-06   ENG     835    18-1101-b     n     831  493574     Z
# 167285       CAB-06   ENG     835    18-1101-b     n     832  493575     Z
# 167286       CAB-06   ENG     835    18-1101-b     n     833  493576     Z
# 167287       CAB-06   ENG     835    18-1101-b     n     834  493577     Z
# 167288       CAB-06   ENG     835    18-1101-b     n     835  493578     Z
#
#         be_id  be_top    c_id                c_created_at c_kind  c_eis  \
# 0         NaN     NaN  224461  2018-03-29 23:10:24.573038      E      0
# 1         NaN     NaN  224462  2018-03-29 23:10:24.595501      E      0
# 2         NaN     NaN  224463  2018-03-29 23:10:24.628362      E      0
# 3         NaN     NaN  224464  2018-03-29 23:10:24.650119      E      0
# 4         NaN     NaN  224465  2018-03-29 23:10:24.670806      E      0
# ...       ...     ...     ...                         ...    ...    ...
# 167284    NaN     NaN  707747  2019-08-31 17:09:28.899814      E      0
# 167285    NaN     NaN  707748  2019-08-31 17:09:28.916381      E      0
# 167286    NaN     NaN  707749  2019-08-31 17:09:28.933088      E      0
# 167287    NaN     NaN  707750  2019-08-31 17:09:28.949515      E      0
# 167288    NaN     NaN  707751  2019-08-31 17:09:28.967937      E      0
#
#         c_base a_role  u_name  \
# 0          NaN     EP  kobest
# 1          NaN     EP  kobest
# 2          NaN     EP  kobest
# 3          NaN     EP  kobest
# 4          NaN     EP  kobest
# ...        ...    ...     ...
# 167284     NaN     EP  kobest
# 167285     NaN     EP  kobest
# 167286     NaN     EP  kobest
# 167287     NaN     EP  kobest
# 167288     NaN     EP  kobest
#
#                                                                                                                                                                                                                                 e_content
# 0                                                                                                                                                                                                                   Let us bow our heads.
# 1       Lord, as we gather here this fine Easter morning, see the little buds pressing their way out, the bees flying in and getting their portion, the birds singing like their hearts would burst with joy, because there is an Easter.
# 2                                                                                                                           We believe that You raised up Jesus from the dead, many years ago, today, and we celebrate this memorial day.
# 3                                                                                                                                                                                       And let there come an Easter among us all, today.
# 4                                                                     May we, as His servants, understand His Word, that we were in His fellowship then, and that now that we are risen with Him and setting together in Heavenly places.
# ...                                                                                                                                                                                                                                   ...
# 167284                                                                                                                                                                                     What else could we desire above Jesus Himself?
# 167285                                                                                                                                                                                     Is He not everything, even Perfect Everything?
# 167286                                                                                                                                                            He that hath an ear let him hear what the Spirit saith to the churches.
# 167287                                                                                                                                                                                                                              Amen.
# 167288                                                                                                                                                                           Even so, Lord God, by Thy Spirit, let us hear Thy truth.
#
# [167289 rows x 18 columns]

# %%
df_E = df_E.drop(['e_id','t_senc','s_typ','e_top','be_id','be_top','c_created_at','c_kind','c_eis','c_base','a_role','u_name'], axis=1) #each record now unique
df_E.iloc[:5,:-1]
# Out:
#   m_descriptor t_lan    t_version  s_rsen    c_id
# 0   1965-0418x   ENG  18-0101-E1R       1  224461
# 1   1965-0418x   ENG  18-0101-E1R       2  224462
# 2   1965-0418x   ENG  18-0101-E1R       3  224463
# 3   1965-0418x   ENG  18-0101-E1R       4  224464
# 4   1965-0418x   ENG  18-0101-E1R       5  224465

# %%
#hide
df_E
# Out:
#        m_descriptor t_lan    t_version  s_rsen    c_id  \
# 0        1965-0418x   ENG  18-0101-E1R       1  224461
# 1        1965-0418x   ENG  18-0101-E1R       2  224462
# 2        1965-0418x   ENG  18-0101-E1R       3  224463
# 3        1965-0418x   ENG  18-0101-E1R       4  224464
# 4        1965-0418x   ENG  18-0101-E1R       5  224465
# ...             ...   ...          ...     ...     ...
# 167284       CAB-06   ENG    18-1101-b     831  707747
# 167285       CAB-06   ENG    18-1101-b     832  707748
# 167286       CAB-06   ENG    18-1101-b     833  707749
# 167287       CAB-06   ENG    18-1101-b     834  707750
# 167288       CAB-06   ENG    18-1101-b     835  707751
#
#                                                                                                                                                                                                                                 e_content
# 0                                                                                                                                                                                                                   Let us bow our heads.
# 1       Lord, as we gather here this fine Easter morning, see the little buds pressing their way out, the bees flying in and getting their portion, the birds singing like their hearts would burst with joy, because there is an Easter.
# 2                                                                                                                           We believe that You raised up Jesus from the dead, many years ago, today, and we celebrate this memorial day.
# 3                                                                                                                                                                                       And let there come an Easter among us all, today.
# 4                                                                     May we, as His servants, understand His Word, that we were in His fellowship then, and that now that we are risen with Him and setting together in Heavenly places.
# ...                                                                                                                                                                                                                                   ...
# 167284                                                                                                                                                                                     What else could we desire above Jesus Himself?
# 167285                                                                                                                                                                                     Is He not everything, even Perfect Everything?
# 167286                                                                                                                                                            He that hath an ear let him hear what the Spirit saith to the churches.
# 167287                                                                                                                                                                                                                              Amen.
# 167288                                                                                                                                                                           Even so, Lord God, by Thy Spirit, let us hear Thy truth.
#
# [167289 rows x 6 columns]

# %%
# 
#handle NaNs in e_content
e_content_nans = df_E['e_content'].isna()
df_E[e_content_nans]
# Out:
#       m_descriptor t_lan  t_version  s_rsen    c_id e_content
# 33415    1956-0805   ENG  15-0402-b    1176  454335       NaN
# 43018    1957-0419   ENG  15-0401-b     505   13306       NaN

# %%
# 
#replace e_content NaNs with empty strings
df_E.loc[e_content_nans, 'e_content'] = ''
# df_E.loc[e_content_nans, ['e_content']]
# OR
df_E[df_E['e_content']=='']
# Out:
#       m_descriptor t_lan  t_version  s_rsen    c_id e_content
# 33415    1956-0805   ENG  15-0402-b    1176  454335
# 43018    1957-0419   ENG  15-0401-b     505   13306

# %%
# 
#add chars column
df_E['chars'] = [len(e) for e in df_E['e_content']]
# df_E['chars'] = [len(e) if type(e)==str else 1 for e in df_E['e_content']]
df_E.loc[:5,['m_descriptor','t_lan','t_version','s_rsen','c_id','chars']]
# Out:
#   m_descriptor t_lan    t_version  s_rsen    c_id  chars
# 0   1965-0418x   ENG  18-0101-E1R       1  224461     21
# 1   1965-0418x   ENG  18-0101-E1R       2  224462    225
# 2   1965-0418x   ENG  18-0101-E1R       3  224463    109
# 3   1965-0418x   ENG  18-0101-E1R       4  224464     49
# 4   1965-0418x   ENG  18-0101-E1R       5  224465    163
# 5   1965-0418x   ENG  18-0101-E1R       6  224466     96

# %%
#hide
df_E
# Out:
#        m_descriptor t_lan    t_version  s_rsen    c_id  \
# 0        1965-0418x   ENG  18-0101-E1R       1  224461
# 1        1965-0418x   ENG  18-0101-E1R       2  224462
# 2        1965-0418x   ENG  18-0101-E1R       3  224463
# 3        1965-0418x   ENG  18-0101-E1R       4  224464
# 4        1965-0418x   ENG  18-0101-E1R       5  224465
# ...             ...   ...          ...     ...     ...
# 167284       CAB-06   ENG    18-1101-b     831  707747
# 167285       CAB-06   ENG    18-1101-b     832  707748
# 167286       CAB-06   ENG    18-1101-b     833  707749
# 167287       CAB-06   ENG    18-1101-b     834  707750
# 167288       CAB-06   ENG    18-1101-b     835  707751
#
#                                                                                                                                                                                                                                 e_content  \
# 0                                                                                                                                                                                                                   Let us bow our heads.
# 1       Lord, as we gather here this fine Easter morning, see the little buds pressing their way out, the bees flying in and getting their portion, the birds singing like their hearts would burst with joy, because there is an Easter.
# 2                                                                                                                           We believe that You raised up Jesus from the dead, many years ago, today, and we celebrate this memorial day.
# 3                                                                                                                                                                                       And let there come an Easter among us all, today.
# 4                                                                     May we, as His servants, understand His Word, that we were in His fellowship then, and that now that we are risen with Him and setting together in Heavenly places.
# ...                                                                                                                                                                                                                                   ...
# 167284                                                                                                                                                                                     What else could we desire above Jesus Himself?
# 167285                                                                                                                                                                                     Is He not everything, even Perfect Everything?
# 167286                                                                                                                                                            He that hath an ear let him hear what the Spirit saith to the churches.
# 167287                                                                                                                                                                                                                              Amen.
# 167288                                                                                                                                                                           Even so, Lord God, by Thy Spirit, let us hear Thy truth.
#
#         chars
# 0          21
# 1         225
# 2         109
# 3          49
# 4         163
# ...       ...
# 167284     46
# 167285     46
# 167286     71
# 167287      5
# 167288     56
#
# [167289 rows x 7 columns]

# %%
# 
# df_E.loc[e_content_nans, ['e_content','chars']]
# OR
df_E[df_E['chars']==0]
# Out:
#       m_descriptor t_lan  t_version  s_rsen    c_id e_content  chars
# 33415    1956-0805   ENG  15-0402-b    1176  454335                0
# 43018    1957-0419   ENG  15-0401-b     505   13306                0

# %%
# 
#add words column
#https://www.geeksforgeeks.org/python-program-to-count-words-in-a-sentence/
df_E['words'] = [len(re.findall(r'\w+', e)) for e in df_E['e_content']]
df_E.loc[:5,['m_descriptor','t_lan','t_version','s_rsen','c_id','chars','words']]
# Out:
#   m_descriptor t_lan    t_version  s_rsen    c_id  chars  words
# 0   1965-0418x   ENG  18-0101-E1R       1  224461     21      5
# 1   1965-0418x   ENG  18-0101-E1R       2  224462    225     40
# 2   1965-0418x   ENG  18-0101-E1R       3  224463    109     20
# 3   1965-0418x   ENG  18-0101-E1R       4  224464     49     10
# 4   1965-0418x   ENG  18-0101-E1R       5  224465    163     30
# 5   1965-0418x   ENG  18-0101-E1R       6  224466     96     17

# %%
#hide
df_E
# Out:
#        m_descriptor t_lan    t_version  s_rsen    c_id  \
# 0        1965-0418x   ENG  18-0101-E1R       1  224461
# 1        1965-0418x   ENG  18-0101-E1R       2  224462
# 2        1965-0418x   ENG  18-0101-E1R       3  224463
# 3        1965-0418x   ENG  18-0101-E1R       4  224464
# 4        1965-0418x   ENG  18-0101-E1R       5  224465
# ...             ...   ...          ...     ...     ...
# 167284       CAB-06   ENG    18-1101-b     831  707747
# 167285       CAB-06   ENG    18-1101-b     832  707748
# 167286       CAB-06   ENG    18-1101-b     833  707749
# 167287       CAB-06   ENG    18-1101-b     834  707750
# 167288       CAB-06   ENG    18-1101-b     835  707751
#
#                                                                                                                                                                                                                                 e_content  \
# 0                                                                                                                                                                                                                   Let us bow our heads.
# 1       Lord, as we gather here this fine Easter morning, see the little buds pressing their way out, the bees flying in and getting their portion, the birds singing like their hearts would burst with joy, because there is an Easter.
# 2                                                                                                                           We believe that You raised up Jesus from the dead, many years ago, today, and we celebrate this memorial day.
# 3                                                                                                                                                                                       And let there come an Easter among us all, today.
# 4                                                                     May we, as His servants, understand His Word, that we were in His fellowship then, and that now that we are risen with Him and setting together in Heavenly places.
# ...                                                                                                                                                                                                                                   ...
# 167284                                                                                                                                                                                     What else could we desire above Jesus Himself?
# 167285                                                                                                                                                                                     Is He not everything, even Perfect Everything?
# 167286                                                                                                                                                            He that hath an ear let him hear what the Spirit saith to the churches.
# 167287                                                                                                                                                                                                                              Amen.
# 167288                                                                                                                                                                           Even so, Lord God, by Thy Spirit, let us hear Thy truth.
#
#         chars  words
# 0          21      5
# 1         225     40
# 2         109     20
# 3          49     10
# 4         163     30
# ...       ...    ...
# 167284     46      8
# 167285     46      7
# 167286     71     15
# 167287      5      1
# 167288     56     12
#
# [167289 rows x 8 columns]

# %%
# 
#remove BER part of version from t_version so that we can use this column to join the English contributions with their matching translated contributions
df_E['t_version'] = ['-'.join(e.split('-')[:2]) for e in df_E['t_version']]
df_E.loc[:5,['m_descriptor','t_lan','t_version','s_rsen','c_id','chars','words']]
# Out:
#   m_descriptor t_lan t_version  s_rsen    c_id  chars  words
# 0   1965-0418x   ENG   18-0101       1  224461     21      5
# 1   1965-0418x   ENG   18-0101       2  224462    225     40
# 2   1965-0418x   ENG   18-0101       3  224463    109     20
# 3   1965-0418x   ENG   18-0101       4  224464     49     10
# 4   1965-0418x   ENG   18-0101       5  224465    163     30
# 5   1965-0418x   ENG   18-0101       6  224466     96     17

# %%
#hide
df_E
# Out:
#        m_descriptor t_lan t_version  s_rsen    c_id  \
# 0        1965-0418x   ENG   18-0101       1  224461
# 1        1965-0418x   ENG   18-0101       2  224462
# 2        1965-0418x   ENG   18-0101       3  224463
# 3        1965-0418x   ENG   18-0101       4  224464
# 4        1965-0418x   ENG   18-0101       5  224465
# ...             ...   ...       ...     ...     ...
# 167284       CAB-06   ENG   18-1101     831  707747
# 167285       CAB-06   ENG   18-1101     832  707748
# 167286       CAB-06   ENG   18-1101     833  707749
# 167287       CAB-06   ENG   18-1101     834  707750
# 167288       CAB-06   ENG   18-1101     835  707751
#
#                                                                                                                                                                                                                                 e_content  \
# 0                                                                                                                                                                                                                   Let us bow our heads.
# 1       Lord, as we gather here this fine Easter morning, see the little buds pressing their way out, the bees flying in and getting their portion, the birds singing like their hearts would burst with joy, because there is an Easter.
# 2                                                                                                                           We believe that You raised up Jesus from the dead, many years ago, today, and we celebrate this memorial day.
# 3                                                                                                                                                                                       And let there come an Easter among us all, today.
# 4                                                                     May we, as His servants, understand His Word, that we were in His fellowship then, and that now that we are risen with Him and setting together in Heavenly places.
# ...                                                                                                                                                                                                                                   ...
# 167284                                                                                                                                                                                     What else could we desire above Jesus Himself?
# 167285                                                                                                                                                                                     Is He not everything, even Perfect Everything?
# 167286                                                                                                                                                            He that hath an ear let him hear what the Spirit saith to the churches.
# 167287                                                                                                                                                                                                                              Amen.
# 167288                                                                                                                                                                           Even so, Lord God, by Thy Spirit, let us hear Thy truth.
#
#         chars  words
# 0          21      5
# 1         225     40
# 2         109     20
# 3          49     10
# 4         163     30
# ...       ...    ...
# 167284     46      8
# 167285     46      7
# 167286     71     15
# 167287      5      1
# 167288     56     12
#
# [167289 rows x 8 columns]

# %% [markdown]
# ## Ingest all V-contributions

# %%
#hide
# df_V = pd.read_csv(f'{PATH}/contributions/1955-0807y_Pride_CHN_15-0401-h_V-contributions.csv', sep='~')
# df_V = pd.read_csv(f'{PATH}/contributions/1965-0829_SatansEden_FIJ_15-1104-B123_V-contributions.csv', sep='~')
# df_V

# %%
all_files = glob.glob(f"{PATH}/contributions/*V-contributions.csv")
li = []
for filename in all_files:
    dft = pd.read_csv(filename, index_col=None, header=0, sep='~')
    li.append(dft)
df_V = pd.concat(li, axis=0, ignore_index=True)
df_V.iloc[:5,:-2]
# Out:
#   m_descriptor t_lan  t_senc        t_version s_typ  s_rsen    e_id e_top  \
# 0   1965-0418x   AFR    1870  18-0101-B123E1R     n       1  181444     M
# 1   1965-0418x   AFR    1870  18-0101-B123E1R     n       1  181444     M
# 2   1965-0418x   AFR    1870  18-0101-B123E1R     n       2  339948     T
# 3   1965-0418x   AFR    1870  18-0101-B123E1R     n       2  200635     N
# 4   1965-0418x   AFR    1870  18-0101-B123E1R     n       3  200637     M
#
#       be_id be_top    c_id                c_created_at c_kind  c_eis c_base  \
# 0  181444.0      M  844713  2020-01-15 02:13:34.847562      V     11      a
# 1  181444.0      M  256723  2018-04-23 11:04:31.787641      V     28      a
# 2  200635.0      N  468379   2019-01-30 22:21:29.62162      V      0      c
# 3  181445.0      N  256725  2018-04-23 11:23:43.781013      V      0      c
# 4  200636.0      N  256727  2018-04-23 11:26:37.965897      V      0      c
#
#   a_role
# 0     CE
# 1     TE
# 2     CE
# 3     TE
# 4     TE

# %%
#hide
df_V
# Out:
#        m_descriptor t_lan  t_senc        t_version s_typ  s_rsen    e_id  \
# 0        1965-0418x   AFR    1870  18-0101-B123E1R     n       1  181444
# 1        1965-0418x   AFR    1870  18-0101-B123E1R     n       1  181444
# 2        1965-0418x   AFR    1870  18-0101-B123E1R     n       2  339948
# 3        1965-0418x   AFR    1870  18-0101-B123E1R     n       2  200635
# 4        1965-0418x   AFR    1870  18-0101-B123E1R     n       3  200637
# ...             ...   ...     ...              ...   ...     ...     ...
# 382737       CAB-06   AFR     835     18-1101-B123     n     833  610356
# 382738       CAB-06   AFR     835     18-1101-B123     n     834  610357
# 382739       CAB-06   AFR     835     18-1101-B123     n     834  610357
# 382740       CAB-06   AFR     835     18-1101-B123     n     835  610358
# 382741       CAB-06   AFR     835     18-1101-B123     n     835  610358
#
#        e_top     be_id be_top     c_id                c_created_at c_kind  \
# 0          M  181444.0      M   844713  2020-01-15 02:13:34.847562      V
# 1          M  181444.0      M   256723  2018-04-23 11:04:31.787641      V
# 2          T  200635.0      N   468379   2019-01-30 22:21:29.62162      V
# 3          N  181445.0      N   256725  2018-04-23 11:23:43.781013      V
# 4          M  200636.0      N   256727  2018-04-23 11:26:37.965897      V
# ...      ...       ...    ...      ...                         ...    ...
# 382737     M  610356.0      M  1061632  2020-05-25 02:44:38.590448      V
# 382738     M  610357.0      M  1061633   2020-05-25 02:44:42.21845      V
# 382739     M  494412.0      N   874368   2020-02-02 00:24:14.79957      V
# 382740     M  610358.0      M  1061634  2020-05-25 02:44:56.991446      V
# 382741     M  494413.0      N   874370  2020-02-02 00:24:42.429672      V
#
#         c_eis c_base a_role  u_name  \
# 0          11      a     CE  engest
# 1          28      a     TE  linoli
# 2           0      c     CE  engest
# 3           0      c     TE  linoli
# 4           0      c     TE  linoli
# ...       ...    ...    ...     ...
# 382737     12      t     CE  engest
# 382738      3      t     CE  engest
# 382739      0      c     TE  tilvan
# 382740     14      t     CE  engest
# 382741      0      c     TE  tilvan
#
#                                                                                                                                                                                                                        e_content
# 0                                                                                                                                                                                                      Laat ons ons hoofde buig.
# 1                                                                                                                                                                                                      Laat ons ons hoofde buig.
# 2       Here, soos ons hier vergader op hierdie mooi Paasfees oggend, sien die botsels uitloop, die bye wat in vlieg en hulle gedeelte kry, die voëls wat sing asof hulle harte wil bars van vreugde, omdat daar 'n Paasfees is.
# 3           Here, soos ons hier vergader op hierdie mooi Paasfees oggend, sien die botsels uitloop, die bye wat in vlieg en hulle gedeelte kry, die voëls wat sing asof hulle harte wil bars van vreugde, omdat daar 'n Pase is.
# 4                                                                                                                         Ons glo dat U Jesus opgewek het uit die dode, baie jare gelede, en vandag vier ons hierdie aandenking.
# ...                                                                                                                                                                                                                          ...
# 382737                                                                                                                                                        Hy wat 'n oor het laat hom hoor wat die Gees aan die gemeentes sê.
# 382738                                                                                                                                                                                                                     Amen.
# 382739                                                                                                                                                                                                                     Amen.
# 382740                                                                                                                                                                Selfs so, Here God, deur U Gees, laat ons U waarheid hoor.
# 382741                                                                                                                                                                Selfs so, Here God, deur U Gees, laat ons U waarheid hoor.
#
# [382742 rows x 18 columns]

# %%
#hide
# print(df_V['be_top'].unique())
# df_V[df_V['be_top'].isna()] #are these due to a bug???
# df_V[df_V['e_top'].isna()]

# %%
df_V = df_V.drop(['t_senc','s_typ','be_id','c_eis'], axis=1)
df_V.iloc[:5,:-2]
# Out:
#   m_descriptor t_lan        t_version  s_rsen    e_id e_top be_top    c_id  \
# 0   1965-0418x   AFR  18-0101-B123E1R       1  181444     M      M  844713
# 1   1965-0418x   AFR  18-0101-B123E1R       1  181444     M      M  256723
# 2   1965-0418x   AFR  18-0101-B123E1R       2  339948     T      N  468379
# 3   1965-0418x   AFR  18-0101-B123E1R       2  200635     N      N  256725
# 4   1965-0418x   AFR  18-0101-B123E1R       3  200637     M      N  256727
#
#                  c_created_at c_kind c_base a_role
# 0  2020-01-15 02:13:34.847562      V      a     CE
# 1  2018-04-23 11:04:31.787641      V      a     TE
# 2   2019-01-30 22:21:29.62162      V      c     CE
# 3  2018-04-23 11:23:43.781013      V      c     TE
# 4  2018-04-23 11:26:37.965897      V      c     TE

# %%
#hide
df_V
# Out:
#        m_descriptor t_lan        t_version  s_rsen    e_id e_top be_top  \
# 0        1965-0418x   AFR  18-0101-B123E1R       1  181444     M      M
# 1        1965-0418x   AFR  18-0101-B123E1R       1  181444     M      M
# 2        1965-0418x   AFR  18-0101-B123E1R       2  339948     T      N
# 3        1965-0418x   AFR  18-0101-B123E1R       2  200635     N      N
# 4        1965-0418x   AFR  18-0101-B123E1R       3  200637     M      N
# ...             ...   ...              ...     ...     ...   ...    ...
# 382737       CAB-06   AFR     18-1101-B123     833  610356     M      M
# 382738       CAB-06   AFR     18-1101-B123     834  610357     M      M
# 382739       CAB-06   AFR     18-1101-B123     834  610357     M      N
# 382740       CAB-06   AFR     18-1101-B123     835  610358     M      M
# 382741       CAB-06   AFR     18-1101-B123     835  610358     M      N
#
#            c_id                c_created_at c_kind c_base a_role  u_name  \
# 0        844713  2020-01-15 02:13:34.847562      V      a     CE  engest
# 1        256723  2018-04-23 11:04:31.787641      V      a     TE  linoli
# 2        468379   2019-01-30 22:21:29.62162      V      c     CE  engest
# 3        256725  2018-04-23 11:23:43.781013      V      c     TE  linoli
# 4        256727  2018-04-23 11:26:37.965897      V      c     TE  linoli
# ...         ...                         ...    ...    ...    ...     ...
# 382737  1061632  2020-05-25 02:44:38.590448      V      t     CE  engest
# 382738  1061633   2020-05-25 02:44:42.21845      V      t     CE  engest
# 382739   874368   2020-02-02 00:24:14.79957      V      c     TE  tilvan
# 382740  1061634  2020-05-25 02:44:56.991446      V      t     CE  engest
# 382741   874370  2020-02-02 00:24:42.429672      V      c     TE  tilvan
#
#                                                                                                                                                                                                                        e_content
# 0                                                                                                                                                                                                      Laat ons ons hoofde buig.
# 1                                                                                                                                                                                                      Laat ons ons hoofde buig.
# 2       Here, soos ons hier vergader op hierdie mooi Paasfees oggend, sien die botsels uitloop, die bye wat in vlieg en hulle gedeelte kry, die voëls wat sing asof hulle harte wil bars van vreugde, omdat daar 'n Paasfees is.
# 3           Here, soos ons hier vergader op hierdie mooi Paasfees oggend, sien die botsels uitloop, die bye wat in vlieg en hulle gedeelte kry, die voëls wat sing asof hulle harte wil bars van vreugde, omdat daar 'n Pase is.
# 4                                                                                                                         Ons glo dat U Jesus opgewek het uit die dode, baie jare gelede, en vandag vier ons hierdie aandenking.
# ...                                                                                                                                                                                                                          ...
# 382737                                                                                                                                                        Hy wat 'n oor het laat hom hoor wat die Gees aan die gemeentes sê.
# 382738                                                                                                                                                                                                                     Amen.
# 382739                                                                                                                                                                                                                     Amen.
# 382740                                                                                                                                                                Selfs so, Here God, deur U Gees, laat ons U waarheid hoor.
# 382741                                                                                                                                                                Selfs so, Here God, deur U Gees, laat ons U waarheid hoor.
#
# [382742 rows x 14 columns]

# %%
#hide
#verify all TE/CE
# df_V[df_V['a_role']=='TE']
# df_V[df_V['a_role']=='CE']

# %%
#hide
#keep only top edits
# df_V['e_top'].unique()
df_V[~df_V['e_top'].isin(['M','T'])] #show others first before reassigning df
# Out:
#        m_descriptor t_lan        t_version  s_rsen    e_id e_top be_top  \
# 3        1965-0418x   AFR  18-0101-B123E1R       2  200635     N      N
# 7        1965-0418x   AFR  18-0101-B123E1R       4  200638     N      N
# 8        1965-0418x   AFR  18-0101-B123E1R       5  200639     N      N
# 14       1965-0418x   AFR  18-0101-B123E1R       8  200640     N      N
# 23       1965-0418x   AFR  18-0101-B123E1R      12  200641     N      N
# ...             ...   ...              ...     ...     ...   ...    ...
# 382705       CAB-06   AFR     18-1101-B123     817  610338     N      N
# 382706       CAB-06   AFR     18-1101-B123     818  610339     N      N
# 382724       CAB-06   AFR     18-1101-B123     827  610348     N      N
# 382728       CAB-06   AFR     18-1101-B123     829  610350     N      N
# 382733       CAB-06   AFR     18-1101-B123     831  610353     N      N
#
#           c_id                c_created_at c_kind c_base a_role  u_name  \
# 3       256725  2018-04-23 11:23:43.781013      V      c     TE  linoli
# 7       256730  2018-04-23 11:31:35.950348      V      c     TE  linoli
# 8       256732  2018-04-23 11:43:02.365621      V      c     TE  linoli
# 14      256736  2018-04-23 11:45:23.928111      V      c     TE  linoli
# 23      256741  2018-04-23 11:52:51.171064      V      c     TE  linoli
# ...        ...                         ...    ...    ...    ...     ...
# 382705  874332  2020-02-02 00:04:25.814695      V      c     TE  tilvan
# 382706  874334  2020-02-02 00:04:55.254216      V      c     TE  tilvan
# 382724  874352  2020-02-02 00:16:15.338023      V      c     TE  tilvan
# 382728  874356  2020-02-02 00:18:14.532886      V      c     TE  tilvan
# 382733  874360  2020-02-02 00:22:32.497847      V      c     TE  tilvan
#
#                                                                                                                                                                                                                    e_content
# 3       Here, soos ons hier vergader op hierdie mooi Paasfees oggend, sien die botsels uitloop, die bye wat in vlieg en hulle gedeelte kry, die voëls wat sing asof hulle harte wil bars van vreugde, omdat daar 'n Pase is.
# 7                                                                                                                                                                         En laat daar tussen ons almal ,'n Pase kom vandag.
# 8                                                                      Mag ons, as Sy diensknegte, Sy Woord verstaan, dat ons in Sy gemeenskap was, en dat ons nou saam met Hom opgestaan het en saam sit in Hemelse plekke.
# 14                                                                                                                                                    Mag dit ook ’n Pase wees vir hulle, en ’n eksodus van siekte tot krag.
# 23         Ek beskou hierdie beslis as ’n wonderlike voorreg, vanmôre om terug te wees hier in Jeffersonville, Indiana, met hierdie groot gemeente, die kerk gepak en staan in en om buitekant, in die parkeer area en oral.
# ...                                                                                                                                                                                                                      ...
# 382705                                                                                                                                          Hulle word ook sterre genoem omdat hulle 'houers' van lig is in die aandtyd.
# 382706                                                                                                                                              Daarom in die donker van sonde, bring hulle die lig van God na Sy mense.
# 382724                                                                                                                                         Hy sal nie die sterre gebruik (boodskappers) om lig te gee in duisternis nie.
# 382728                                                                                                                                            Dit is die môrester wat sigbaar is wanneer die lig van die son begin skyn.
# 382733                                                                                                                                                                     Wat anders kan ons begeer behalwe Jesus Homself ?
#
# [20637 rows x 14 columns]

# %%
# 
#keep only top edits
# df_V[df_V['e_top'].isin(['M','T'])] #Majority & Tie
df_V = df_V[df_V['e_top'].isin(['M','T'])] #Majority & Tie
df_V.iloc[:5,:-2]
# Out:
#   m_descriptor t_lan        t_version  s_rsen    e_id e_top be_top    c_id  \
# 0   1965-0418x   AFR  18-0101-B123E1R       1  181444     M      M  844713
# 1   1965-0418x   AFR  18-0101-B123E1R       1  181444     M      M  256723
# 2   1965-0418x   AFR  18-0101-B123E1R       2  339948     T      N  468379
# 4   1965-0418x   AFR  18-0101-B123E1R       3  200637     M      N  256727
# 5   1965-0418x   AFR  18-0101-B123E1R       3  200637     M      M  468380
#
#                  c_created_at c_kind c_base a_role
# 0  2020-01-15 02:13:34.847562      V      a     CE
# 1  2018-04-23 11:04:31.787641      V      a     TE
# 2   2019-01-30 22:21:29.62162      V      c     CE
# 4  2018-04-23 11:26:37.965897      V      c     TE
# 5  2019-01-30 22:21:51.780404      V      t     CE

# %%
#hide
df_V
# Out:
#        m_descriptor t_lan        t_version  s_rsen    e_id e_top be_top  \
# 0        1965-0418x   AFR  18-0101-B123E1R       1  181444     M      M
# 1        1965-0418x   AFR  18-0101-B123E1R       1  181444     M      M
# 2        1965-0418x   AFR  18-0101-B123E1R       2  339948     T      N
# 4        1965-0418x   AFR  18-0101-B123E1R       3  200637     M      N
# 5        1965-0418x   AFR  18-0101-B123E1R       3  200637     M      M
# ...             ...   ...              ...     ...     ...   ...    ...
# 382737       CAB-06   AFR     18-1101-B123     833  610356     M      M
# 382738       CAB-06   AFR     18-1101-B123     834  610357     M      M
# 382739       CAB-06   AFR     18-1101-B123     834  610357     M      N
# 382740       CAB-06   AFR     18-1101-B123     835  610358     M      M
# 382741       CAB-06   AFR     18-1101-B123     835  610358     M      N
#
#            c_id                c_created_at c_kind c_base a_role  u_name  \
# 0        844713  2020-01-15 02:13:34.847562      V      a     CE  engest
# 1        256723  2018-04-23 11:04:31.787641      V      a     TE  linoli
# 2        468379   2019-01-30 22:21:29.62162      V      c     CE  engest
# 4        256727  2018-04-23 11:26:37.965897      V      c     TE  linoli
# 5        468380  2019-01-30 22:21:51.780404      V      t     CE  engest
# ...         ...                         ...    ...    ...    ...     ...
# 382737  1061632  2020-05-25 02:44:38.590448      V      t     CE  engest
# 382738  1061633   2020-05-25 02:44:42.21845      V      t     CE  engest
# 382739   874368   2020-02-02 00:24:14.79957      V      c     TE  tilvan
# 382740  1061634  2020-05-25 02:44:56.991446      V      t     CE  engest
# 382741   874370  2020-02-02 00:24:42.429672      V      c     TE  tilvan
#
#                                                                                                                                                                                                                        e_content
# 0                                                                                                                                                                                                      Laat ons ons hoofde buig.
# 1                                                                                                                                                                                                      Laat ons ons hoofde buig.
# 2       Here, soos ons hier vergader op hierdie mooi Paasfees oggend, sien die botsels uitloop, die bye wat in vlieg en hulle gedeelte kry, die voëls wat sing asof hulle harte wil bars van vreugde, omdat daar 'n Paasfees is.
# 4                                                                                                                         Ons glo dat U Jesus opgewek het uit die dode, baie jare gelede, en vandag vier ons hierdie aandenking.
# 5                                                                                                                         Ons glo dat U Jesus opgewek het uit die dode, baie jare gelede, en vandag vier ons hierdie aandenking.
# ...                                                                                                                                                                                                                          ...
# 382737                                                                                                                                                        Hy wat 'n oor het laat hom hoor wat die Gees aan die gemeentes sê.
# 382738                                                                                                                                                                                                                     Amen.
# 382739                                                                                                                                                                                                                     Amen.
# 382740                                                                                                                                                                Selfs so, Here God, deur U Gees, laat ons U waarheid hoor.
# 382741                                                                                                                                                                Selfs so, Here God, deur U Gees, laat ons U waarheid hoor.
#
# [362105 rows x 14 columns]

# %%
tmp = df_V.sort_values(by=['m_descriptor', 't_lan','t_version','s_rsen','c_created_at'])

# %%
#hide
tmp
# Out:
#        m_descriptor t_lan     t_version  s_rsen    e_id e_top be_top     c_id  \
# 6405      1948-0304   GER  15-0902-B123       1  464917     M    NaN   662736
# 6406      1948-0304   GER  15-0902-B123       2  456140     M      M   662737
# 6407      1948-0304   GER  15-0902-B123       3  456141     M      M   662738
# 6408      1948-0304   GER  15-0902-B123       4  456142     M      M   662739
# 6409      1948-0304   GER  15-0902-B123       5  457312     M      N   662741
# ...             ...   ...           ...     ...     ...   ...    ...      ...
# 382737       CAB-06   AFR  18-1101-B123     833  610356     M      M  1061632
# 382739       CAB-06   AFR  18-1101-B123     834  610357     M      N   874368
# 382738       CAB-06   AFR  18-1101-B123     834  610357     M      M  1061633
# 382741       CAB-06   AFR  18-1101-B123     835  610358     M      N   874370
# 382740       CAB-06   AFR  18-1101-B123     835  610358     M      M  1061634
#
#                       c_created_at c_kind c_base a_role  u_name  \
# 6405    2019-07-30 13:44:14.904495      V      c     TE  hugmes
# 6406    2019-07-30 13:44:34.151158      V      a     TE  hugmes
# 6407    2019-07-30 13:44:45.966924      V      a     TE  hugmes
# 6408    2019-07-30 13:44:53.096079      V      a     TE  hugmes
# 6409    2019-07-30 13:45:56.611909      V      c     TE  hugmes
# ...                            ...    ...    ...    ...     ...
# 382737  2020-05-25 02:44:38.590448      V      t     CE  engest
# 382739   2020-02-02 00:24:14.79957      V      c     TE  tilvan
# 382738   2020-05-25 02:44:42.21845      V      t     CE  engest
# 382741  2020-02-02 00:24:42.429672      V      c     TE  tilvan
# 382740  2020-05-25 02:44:56.991446      V      t     CE  engest
#
#                                                                                                                e_content
# 6405    Gehen Sie jetzt nicht von hier weg und sagen Sie: „Bruder Branham sagte, es sind zehn Jahre bis zur Entrückung."
# 6406                                                                                        Ich weiß nicht; niemand tut.
# 6407                                                                           Nicht einmal die Engel des Himmels kennt.
# 6408                                                                                                  Ich weiß es nicht.
# 6409          Aber ich weiß, dass es in der Nähe schrecklich wird, denn die Anzeichen, die Er sagte, würden stattfinden.
# ...                                                                                                                  ...
# 382737                                                Hy wat 'n oor het laat hom hoor wat die Gees aan die gemeentes sê.
# 382739                                                                                                             Amen.
# 382738                                                                                                             Amen.
# 382741                                                        Selfs so, Here God, deur U Gees, laat ons U waarheid hoor.
# 382740                                                        Selfs so, Here God, deur U Gees, laat ons U waarheid hoor.
#
# [362105 rows x 14 columns]

# %%
#hide
del tmp

# %%
df_V = df_V.groupby(['m_descriptor', 't_lan','t_version','s_rsen']).agg({'e_top':'last', 'be_top':'last', 'c_created_at':['last','count'], 'c_kind':'last', 'c_base':'last', 'a_role':'last', 'u_name':'last', 'e_content':'last'})
df_V.iloc[:,:-2]
# Out:
#                                        e_top be_top  \
#                                         last   last
# m_descriptor t_lan t_version    s_rsen
# 1948-0304    GER   15-0902-B123 1          M    NaN
#                                 2          M      M
#                                 3          M      M
#                                 4          M      M
#                                 5          M      N
# ...                                      ...    ...
# CAB-06       AFR   18-1101-B123 831        T      N
#                                 832        M      M
#                                 833        M      M
#                                 834        M      N
#                                 835        M      N
#
#                                                       c_created_at        \
#                                                               last count
# m_descriptor t_lan t_version    s_rsen
# 1948-0304    GER   15-0902-B123 1       2019-07-30 13:44:14.904495     1
#                                 2       2019-07-30 13:44:34.151158     1
#                                 3       2019-07-30 13:44:45.966924     1
#                                 4       2019-07-30 13:44:53.096079     1
#                                 5       2019-07-30 13:45:56.611909     1
# ...                                                            ...   ...
# CAB-06       AFR   18-1101-B123 831     2020-05-25 02:43:59.956802     1
#                                 832     2020-05-25 02:44:26.239919     2
#                                 833     2020-05-25 02:44:38.590448     2
#                                 834      2020-02-02 00:24:14.79957     2
#                                 835     2020-02-02 00:24:42.429672     2
#
#                                        c_kind c_base a_role
#                                          last   last   last
# m_descriptor t_lan t_version    s_rsen
# 1948-0304    GER   15-0902-B123 1           V      c     TE
#                                 2           V      a     TE
#                                 3           V      a     TE
#                                 4           V      a     TE
#                                 5           V      c     TE
# ...                                       ...    ...    ...
# CAB-06       AFR   18-1101-B123 831         V      c     CE
#                                 832         V      t     CE
#                                 833         V      t     CE
#                                 834         V      c     TE
#                                 835         V      c     TE
#
# [248389 rows x 7 columns]

# %%
#hide
df_V
# Out:
#                                        e_top be_top  \
#                                         last   last
# m_descriptor t_lan t_version    s_rsen
# 1948-0304    GER   15-0902-B123 1          M    NaN
#                                 2          M      M
#                                 3          M      M
#                                 4          M      M
#                                 5          M      N
# ...                                      ...    ...
# CAB-06       AFR   18-1101-B123 831        T      N
#                                 832        M      M
#                                 833        M      M
#                                 834        M      N
#                                 835        M      N
#
#                                                       c_created_at        \
#                                                               last count
# m_descriptor t_lan t_version    s_rsen
# 1948-0304    GER   15-0902-B123 1       2019-07-30 13:44:14.904495     1
#                                 2       2019-07-30 13:44:34.151158     1
#                                 3       2019-07-30 13:44:45.966924     1
#                                 4       2019-07-30 13:44:53.096079     1
#                                 5       2019-07-30 13:45:56.611909     1
# ...                                                            ...   ...
# CAB-06       AFR   18-1101-B123 831     2020-05-25 02:43:59.956802     1
#                                 832     2020-05-25 02:44:26.239919     2
#                                 833     2020-05-25 02:44:38.590448     2
#                                 834      2020-02-02 00:24:14.79957     2
#                                 835     2020-02-02 00:24:42.429672     2
#
#                                        c_kind c_base a_role  u_name  \
#                                          last   last   last    last
# m_descriptor t_lan t_version    s_rsen
# 1948-0304    GER   15-0902-B123 1           V      c     TE  hugmes
#                                 2           V      a     TE  hugmes
#                                 3           V      a     TE  hugmes
#                                 4           V      a     TE  hugmes
#                                 5           V      c     TE  hugmes
# ...                                       ...    ...    ...     ...
# CAB-06       AFR   18-1101-B123 831         V      c     CE  engest
#                                 832         V      t     CE  engest
#                                 833         V      t     CE  engest
#                                 834         V      c     TE  tilvan
#                                 835         V      c     TE  tilvan
#
#                                                                                                                                                e_content
#                                                                                                                                                     last
# m_descriptor t_lan t_version    s_rsen
# 1948-0304    GER   15-0902-B123 1       Gehen Sie jetzt nicht von hier weg und sagen Sie: „Bruder Branham sagte, es sind zehn Jahre bis zur Entrückung."
#                                 2                                                                                           Ich weiß nicht; niemand tut.
#                                 3                                                                              Nicht einmal die Engel des Himmels kennt.
#                                 4                                                                                                     Ich weiß es nicht.
#                                 5             Aber ich weiß, dass es in der Nähe schrecklich wird, denn die Anzeichen, die Er sagte, würden stattfinden.
# ...                                                                                                                                                  ...
# CAB-06       AFR   18-1101-B123 831                                                                     Wat anders kan ons begeer behalwe Jesus Homself?
#                                 832                                                                            Is Hy nie alles nie, selfs Volmaak Alles?
#                                 833                                                   Hy wat 'n oor het laat hom hoor wat die Gees aan die gemeentes sê.
#                                 834                                                                                                                Amen.
#                                 835                                                           Selfs so, Here God, deur U Gees, laat ons U waarheid hoor.
#
# [248389 rows x 9 columns]

# %%
# 
# use T-contributions.csv to verify that all sentences have votes (i.e. no red ones left)

# %%
#hide
# df_T = pd.read_csv(f'{PATH}/contributions/1955-0807y_Pride_CHN_15-0401-h_T-contributions.csv', sep='~')
# df_T = pd.read_csv(f'{PATH}/contributions/1965-0829_SatansEden_FIJ_15-1104-B123_T-contributions.csv', sep='~')
# df_T

# %%
all_files = glob.glob(f"{PATH}/contributions/*T-contributions.csv")
li = []
for filename in all_files:
    dft = pd.read_csv(filename, index_col=None, header=0, sep='~')
    li.append(dft)
df_T = pd.concat(li, axis=0, ignore_index=True)
df_T.iloc[:5,:-2]
# Out:
#   m_descriptor t_lan  t_senc        t_version s_typ  s_rsen    e_id e_top  \
# 0   1965-0418x   AFR    1870  18-0101-B123E1R     n       1  181444     M
# 1   1965-0418x   AFR    1870  18-0101-B123E1R     n       2  181445     N
# 2   1965-0418x   AFR    1870  18-0101-B123E1R     n       3  181446     N
# 3   1965-0418x   AFR    1870  18-0101-B123E1R     n       4  181447     N
# 4   1965-0418x   AFR    1870  18-0101-B123E1R     n       5  181448     N
#
#    be_id  be_top    c_id                c_created_at c_kind  c_eis  c_base  \
# 0    NaN     NaN  231225  2018-03-30 13:05:50.489319      T      0     NaN
# 1    NaN     NaN  231226  2018-03-30 13:05:50.524888      T      0     NaN
# 2    NaN     NaN  231227   2018-03-30 13:05:50.56683      T      0     NaN
# 3    NaN     NaN  231228  2018-03-30 13:05:50.601543      T      0     NaN
# 4    NaN     NaN  231229  2018-03-30 13:05:50.635029      T      0     NaN
#
#   a_role
# 0     MT
# 1     MT
# 2     MT
# 3     MT
# 4     MT

# %%
#hide
df_T
# Out:
#        m_descriptor t_lan  t_senc        t_version s_typ  s_rsen    e_id  \
# 0        1965-0418x   AFR    1870  18-0101-B123E1R     n       1  181444
# 1        1965-0418x   AFR    1870  18-0101-B123E1R     n       2  181445
# 2        1965-0418x   AFR    1870  18-0101-B123E1R     n       3  181446
# 3        1965-0418x   AFR    1870  18-0101-B123E1R     n       4  181447
# 4        1965-0418x   AFR    1870  18-0101-B123E1R     n       5  181448
# ...             ...   ...     ...              ...   ...     ...     ...
# 248384       CAB-06   AFR     835     18-1101-B123     n     831  494409
# 248385       CAB-06   AFR     835     18-1101-B123     n     832  494410
# 248386       CAB-06   AFR     835     18-1101-B123     n     833  494411
# 248387       CAB-06   AFR     835     18-1101-B123     n     834  494412
# 248388       CAB-06   AFR     835     18-1101-B123     n     835  494413
#
#        e_top  be_id  be_top    c_id                c_created_at c_kind  c_eis  \
# 0          M    NaN     NaN  231225  2018-03-30 13:05:50.489319      T      0
# 1          N    NaN     NaN  231226  2018-03-30 13:05:50.524888      T      0
# 2          N    NaN     NaN  231227   2018-03-30 13:05:50.56683      T      0
# 3          N    NaN     NaN  231228  2018-03-30 13:05:50.601543      T      0
# 4          N    NaN     NaN  231229  2018-03-30 13:05:50.635029      T      0
# ...      ...    ...     ...     ...                         ...    ...    ...
# 248384     N    NaN     NaN  708583  2019-08-31 17:18:46.983416      T      0
# 248385     N    NaN     NaN  708584  2019-08-31 17:18:46.998927      T      0
# 248386     N    NaN     NaN  708585  2019-08-31 17:18:47.017601      T      0
# 248387     N    NaN     NaN  708586  2019-08-31 17:18:47.034374      T      0
# 248388     N    NaN     NaN  708587  2019-08-31 17:18:47.054954      T      0
#
#         c_base a_role       u_name  \
# 0          NaN     MT  todmo-2.0.0
# 1          NaN     MT  todmo-2.0.0
# 2          NaN     MT  todmo-2.0.0
# 3          NaN     MT  todmo-2.0.0
# 4          NaN     MT  todmo-2.0.0
# ...        ...    ...          ...
# 248384     NaN     MT        todnt
# 248385     NaN     MT        todnt
# 248386     NaN     MT        todnt
# 248387     NaN     MT        todnt
# 248388     NaN     MT        todnt
#
#                                                                                                                                                                                                                       e_content
# 0                                                                                                                                                                                                     Laat ons ons hoofde buig.
# 1       Here, soos ons hier vergader hierdie mooi Paasoggend, sien die knoppies druk op hulle manier uit, die bye vlieg in en kry hulle gedeelte, die voëls het gesing soos hulle harte bars met vreugde, want daar is ’n Pase.
# 2                                                                                                                   Ons glo dat U Jesus opgewek het uit die dood, baie jare gelede, vandag, en ons vier hierdie aandenking dag.
# 3                                                                                                                                                                            En laat daar kom ’n Pase tussen ons almal, vandag.
# 4                                                                     Mag ons, as Sy diensknegte, verstaan, dat ons Sy Woord was in Sy gemeenskap dan, en dit wat ons nou opgestaan saam met Hom en saam sit in Hemelse plekke.
# ...                                                                                                                                                                                                                         ...
# 248384                                                                                                                                                                Waarskuwings wat anders kon ons bokant Jesus Self begeer?
# 248385                                                                                                                                                                      Sagmoedig Is Hy nie alles nie, selfs Volmaak Alles?
# 248386                                                                                                                                                 Sagmoedig Hy wat 'n oor laat hoor het wat die Gees aan die gemeentes sê.
# 248387                                                                                                                                                                                                           Vice heiliges.
# 248388                                                                                                                                                        Sagmoedig Selfs, Here God, deur U Gees, laat ons U waarheid hoor.
#
# [248389 rows x 18 columns]

# %%
assert len(df_V)==len(df_T), f"df_V has different length from df_T: Maybe there are sentences without any votes (red ones)!. This means there are contributions such that df_T['e_top']=='Z'"

# %%
# 
#IF PREVIOUS ASSERTION FAILS: See if there are: if so, go vote for them and run this notebook again. This is unusual because each translation's CE should have voted (i.e. signed off on) for ALL sentences!!!
df_T[df_T['e_top']=='Z']
# Out:
# Empty DataFrame
# Columns: [m_descriptor, t_lan, t_senc, t_version, s_typ, s_rsen, e_id, e_top, be_id, be_top, c_id, c_created_at, c_kind, c_eis, c_base, a_role, u_name, e_content]
# Index: []

# %%
df_T[~df_T['e_top'].isin(['M','T','Z','N'])]
# Out:
# Empty DataFrame
# Columns: [m_descriptor, t_lan, t_senc, t_version, s_typ, s_rsen, e_id, e_top, be_id, be_top, c_id, c_created_at, c_kind, c_eis, c_base, a_role, u_name, e_content]
# Index: []

# %%
df_V = df_V.reset_index()
df_V.iloc[:5,:-2]
# Out:
#   m_descriptor t_lan     t_version s_rsen e_top be_top  \
#                                            last   last
# 0    1948-0304   GER  15-0902-B123      1     M    NaN
# 1    1948-0304   GER  15-0902-B123      2     M      M
# 2    1948-0304   GER  15-0902-B123      3     M      M
# 3    1948-0304   GER  15-0902-B123      4     M      M
# 4    1948-0304   GER  15-0902-B123      5     M      N
#
#                  c_created_at       c_kind c_base a_role
#                          last count   last   last   last
# 0  2019-07-30 13:44:14.904495     1      V      c     TE
# 1  2019-07-30 13:44:34.151158     1      V      a     TE
# 2  2019-07-30 13:44:45.966924     1      V      a     TE
# 3  2019-07-30 13:44:53.096079     1      V      a     TE
# 4  2019-07-30 13:45:56.611909     1      V      c     TE

# %%
#hide
df_V
# Out:
#        m_descriptor t_lan     t_version s_rsen e_top be_top  \
#                                                 last   last
# 0         1948-0304   GER  15-0902-B123      1     M    NaN
# 1         1948-0304   GER  15-0902-B123      2     M      M
# 2         1948-0304   GER  15-0902-B123      3     M      M
# 3         1948-0304   GER  15-0902-B123      4     M      M
# 4         1948-0304   GER  15-0902-B123      5     M      N
# ...             ...   ...           ...    ...   ...    ...
# 248384       CAB-06   AFR  18-1101-B123    831     T      N
# 248385       CAB-06   AFR  18-1101-B123    832     M      M
# 248386       CAB-06   AFR  18-1101-B123    833     M      M
# 248387       CAB-06   AFR  18-1101-B123    834     M      N
# 248388       CAB-06   AFR  18-1101-B123    835     M      N
#
#                       c_created_at       c_kind c_base a_role  u_name  \
#                               last count   last   last   last    last
# 0       2019-07-30 13:44:14.904495     1      V      c     TE  hugmes
# 1       2019-07-30 13:44:34.151158     1      V      a     TE  hugmes
# 2       2019-07-30 13:44:45.966924     1      V      a     TE  hugmes
# 3       2019-07-30 13:44:53.096079     1      V      a     TE  hugmes
# 4       2019-07-30 13:45:56.611909     1      V      c     TE  hugmes
# ...                            ...   ...    ...    ...    ...     ...
# 248384  2020-05-25 02:43:59.956802     1      V      c     CE  engest
# 248385  2020-05-25 02:44:26.239919     2      V      t     CE  engest
# 248386  2020-05-25 02:44:38.590448     2      V      t     CE  engest
# 248387   2020-02-02 00:24:14.79957     2      V      c     TE  tilvan
# 248388  2020-02-02 00:24:42.429672     2      V      c     TE  tilvan
#
#                                                                                                                e_content
#                                                                                                                     last
# 0       Gehen Sie jetzt nicht von hier weg und sagen Sie: „Bruder Branham sagte, es sind zehn Jahre bis zur Entrückung."
# 1                                                                                           Ich weiß nicht; niemand tut.
# 2                                                                              Nicht einmal die Engel des Himmels kennt.
# 3                                                                                                     Ich weiß es nicht.
# 4             Aber ich weiß, dass es in der Nähe schrecklich wird, denn die Anzeichen, die Er sagte, würden stattfinden.
# ...                                                                                                                  ...
# 248384                                                                  Wat anders kan ons begeer behalwe Jesus Homself?
# 248385                                                                         Is Hy nie alles nie, selfs Volmaak Alles?
# 248386                                                Hy wat 'n oor het laat hom hoor wat die Gees aan die gemeentes sê.
# 248387                                                                                                             Amen.
# 248388                                                        Selfs so, Here God, deur U Gees, laat ons U waarheid hoor.
#
# [248389 rows x 13 columns]

# %%
df_V.columns
# Out:
# MultiIndex([('m_descriptor',      ''),
#             (       't_lan',      ''),
#             (   't_version',      ''),
#             (      's_rsen',      ''),
#             (       'e_top',  'last'),
#             (      'be_top',  'last'),
#             ('c_created_at',  'last'),
#             ('c_created_at', 'count'),
#             (      'c_kind',  'last'),
#             (      'c_base',  'last'),
#             (      'a_role',  'last'),
#             (      'u_name',  'last'),
#             (   'e_content',  'last')],
#            )

# %%
#
#rename columns
df_V.columns = ['m_descriptor','t_lan','t_version','s_rsen','e_top','be_top','c_created_at','count','c_kind','c_base','a_role','u_name','e_content']

# %%
#hide
df_V
# Out:
#        m_descriptor t_lan     t_version  s_rsen e_top be_top  \
# 0         1948-0304   GER  15-0902-B123       1     M    NaN
# 1         1948-0304   GER  15-0902-B123       2     M      M
# 2         1948-0304   GER  15-0902-B123       3     M      M
# 3         1948-0304   GER  15-0902-B123       4     M      M
# 4         1948-0304   GER  15-0902-B123       5     M      N
# ...             ...   ...           ...     ...   ...    ...
# 248384       CAB-06   AFR  18-1101-B123     831     T      N
# 248385       CAB-06   AFR  18-1101-B123     832     M      M
# 248386       CAB-06   AFR  18-1101-B123     833     M      M
# 248387       CAB-06   AFR  18-1101-B123     834     M      N
# 248388       CAB-06   AFR  18-1101-B123     835     M      N
#
#                       c_created_at  count c_kind c_base a_role  u_name  \
# 0       2019-07-30 13:44:14.904495      1      V      c     TE  hugmes
# 1       2019-07-30 13:44:34.151158      1      V      a     TE  hugmes
# 2       2019-07-30 13:44:45.966924      1      V      a     TE  hugmes
# 3       2019-07-30 13:44:53.096079      1      V      a     TE  hugmes
# 4       2019-07-30 13:45:56.611909      1      V      c     TE  hugmes
# ...                            ...    ...    ...    ...    ...     ...
# 248384  2020-05-25 02:43:59.956802      1      V      c     CE  engest
# 248385  2020-05-25 02:44:26.239919      2      V      t     CE  engest
# 248386  2020-05-25 02:44:38.590448      2      V      t     CE  engest
# 248387   2020-02-02 00:24:14.79957      2      V      c     TE  tilvan
# 248388  2020-02-02 00:24:42.429672      2      V      c     TE  tilvan
#
#                                                                                                                e_content
# 0       Gehen Sie jetzt nicht von hier weg und sagen Sie: „Bruder Branham sagte, es sind zehn Jahre bis zur Entrückung."
# 1                                                                                           Ich weiß nicht; niemand tut.
# 2                                                                              Nicht einmal die Engel des Himmels kennt.
# 3                                                                                                     Ich weiß es nicht.
# 4             Aber ich weiß, dass es in der Nähe schrecklich wird, denn die Anzeichen, die Er sagte, würden stattfinden.
# ...                                                                                                                  ...
# 248384                                                                  Wat anders kan ons begeer behalwe Jesus Homself?
# 248385                                                                         Is Hy nie alles nie, selfs Volmaak Alles?
# 248386                                                Hy wat 'n oor het laat hom hoor wat die Gees aan die gemeentes sê.
# 248387                                                                                                             Amen.
# 248388                                                        Selfs so, Here God, deur U Gees, laat ons U waarheid hoor.
#
# [248389 rows x 13 columns]

# %%
#hide
df_V[~df_V['e_top'].isin(['M','T','Z','N'])]
# Out:
# Empty DataFrame
# Columns: [m_descriptor, t_lan, t_version, s_rsen, e_top, be_top, c_created_at, count, c_kind, c_base, a_role, u_name, e_content]
# Index: []

# %%
#hide
len(df_V[df_V['a_role']=='CE']) + len(df_V[df_V['a_role']=='TE']) + len(df_V[df_V['a_role']=='QE']) + len(df_V[df_V['a_role']=='LA'])
# Out:
# 248389

# %%
#hide
len( df_V[~df_V['a_role'].isin(['CE','TE','QE'])] ) #seems like votes by LA do NOT show in TODPROOF - bug??
# Out:
# 165

# %%
#hide
len(df_V[df_V['a_role']=='LA'])
# len(df_V[df_V['a_role']=='EP'])
# Out:
# 165

# %%
#hide
df_V[~df_V['a_role'].isin(['CE','TE','QE','LA'])]
# Out:
# Empty DataFrame
# Columns: [m_descriptor, t_lan, t_version, s_rsen, e_top, be_top, c_created_at, count, c_kind, c_base, a_role, u_name, e_content]
# Index: []

# %%
# 
#handle NaNs in e_content
e_content_nans = df_V['e_content'].isna()

# %%
#hide
df_V[e_content_nans]
# Out:
#       m_descriptor t_lan     t_version  s_rsen e_top be_top  \
# 15724   1953-0405s   CHN     19-0201-h    1102     M      M
# 15775   1953-0405s   CHN     19-0201-h    1153     M      M
# 30871    1955-1118   CHN     15-0401-h      18     M      M
# 33361    1956-0805   CHN     15-0402-h    1176     M      M
# 34819    1957-0114   CHN     19-0701-h    1204     M      M
# 35746   1957-0120x   CHN     19-0701-h     360     M      M
# 42964    1957-0419   BEM  15-0401-B123     505     M      M
# 55587    1960-0607   CHN     19-0401-h     123     M      M
# 55749    1960-0607   CHN     19-0401-h     285     M      M
# 56098    1960-0607   CHN     19-0401-h     634     M      M
# 56326    1960-0607   CHN     19-0401-h     862     M      M
# 56361    1960-0607   CHN     19-0401-h     897     M      M
# 56362    1960-0607   CHN     19-0401-h     898     M      M
# 56363    1960-0607   CHN     19-0401-h     899     M      M
# 56364    1960-0607   CHN     19-0401-h     900     M      M
# 56365    1960-0607   CHN     19-0401-h     901     M      M
# 56366    1960-0607   CHN     19-0401-h     902     M      M
# 56367    1960-0607   CHN     19-0401-h     903     M      M
# 56368    1960-0607   CHN     19-0401-h     904     M      M
# 56369    1960-0607   CHN     19-0401-h     905     M      M
# 56370    1960-0607   CHN     19-0401-h     906     M      M
# 56371    1960-0607   CHN     19-0401-h     907     M      M
# 56372    1960-0607   CHN     19-0401-h     908     M      M
# 56616    1960-0607   CHN     19-0401-h    1152     M      M
# 56617    1960-0607   CHN     19-0401-h    1153     M      M
#
#                      c_created_at  count c_kind c_base a_role  u_name  \
# 15724  2019-06-11 09:12:28.088006      1      V      a     TE  dawnxu
# 15775  2019-06-15 03:25:11.855078      1      V      a     TE  dawnxu
# 30871  2018-01-06 19:20:40.907983      1      V      a     TE  estzhe
# 33361  2019-07-24 00:12:14.971666      1      V      a     TE  corche
# 34819  2020-05-13 03:47:44.384779      1      V      a     TE  dawnxu
# 35746  2020-02-01 06:08:24.434038      1      V      a     TE  dawnxu
# 42964  2019-05-31 07:05:46.896578      2      V      a     CE  marmwa
# 55587  2019-08-20 13:16:51.415398      1      V      a     TE  dawnxu
# 55749  2019-08-27 01:45:11.773081      1      V      a     TE  dawnxu
# 56098  2019-09-01 02:36:08.515518      1      V      a     TE  dawnxu
# 56326  2019-09-10 04:13:59.529688      1      V      a     TE  dawnxu
# 56361   2019-09-10 04:21:49.99019      1      V      a     TE  dawnxu
# 56362  2019-09-10 04:22:02.231998      1      V      a     TE  dawnxu
# 56363  2019-09-10 04:22:08.276047      1      V      a     TE  dawnxu
# 56364  2019-09-10 04:22:37.933537      1      V      a     TE  dawnxu
# 56365  2019-09-10 04:22:50.554829      1      V      a     TE  dawnxu
# 56366  2019-09-10 04:23:02.436897      1      V      a     TE  dawnxu
# 56367  2019-09-10 04:23:09.395605      1      V      a     TE  dawnxu
# 56368  2019-09-10 04:23:22.975408      1      V      a     TE  dawnxu
# 56369  2019-09-10 04:23:34.411307      1      V      a     TE  dawnxu
# 56370   2019-09-10 04:23:47.23145      1      V      a     TE  dawnxu
# 56371  2019-09-10 04:24:00.698148      1      V      a     TE  dawnxu
# 56372  2019-09-10 04:24:12.476136      1      V      a     TE  dawnxu
# 56616  2019-09-13 22:35:58.779078      1      V      a     TE  dawnxu
# 56617  2019-09-13 22:36:09.230981      1      V      a     TE  dawnxu
#
#       e_content
# 15724       NaN
# 15775       NaN
# 30871       NaN
# 33361       NaN
# 34819       NaN
# 35746       NaN
# 42964       NaN
# 55587       NaN
# 55749       NaN
# 56098       NaN
# 56326       NaN
# 56361       NaN
# 56362       NaN
# 56363       NaN
# 56364       NaN
# 56365       NaN
# 56366       NaN
# 56367       NaN
# 56368       NaN
# 56369       NaN
# 56370       NaN
# 56371       NaN
# 56372       NaN
# 56616       NaN
# 56617       NaN

# %%
# 
#replace e_content NaNs with empty strings
df_V.loc[e_content_nans, 'e_content'] = ''

# %%
#hide
# df_V.loc[e_content_nans, ['e_content']]
# OR
df_V[df_V['e_content']=='']
# Out:
#       m_descriptor t_lan     t_version  s_rsen e_top be_top  \
# 15724   1953-0405s   CHN     19-0201-h    1102     M      M
# 15775   1953-0405s   CHN     19-0201-h    1153     M      M
# 30871    1955-1118   CHN     15-0401-h      18     M      M
# 33361    1956-0805   CHN     15-0402-h    1176     M      M
# 34819    1957-0114   CHN     19-0701-h    1204     M      M
# 35746   1957-0120x   CHN     19-0701-h     360     M      M
# 42964    1957-0419   BEM  15-0401-B123     505     M      M
# 55587    1960-0607   CHN     19-0401-h     123     M      M
# 55749    1960-0607   CHN     19-0401-h     285     M      M
# 56098    1960-0607   CHN     19-0401-h     634     M      M
# 56326    1960-0607   CHN     19-0401-h     862     M      M
# 56361    1960-0607   CHN     19-0401-h     897     M      M
# 56362    1960-0607   CHN     19-0401-h     898     M      M
# 56363    1960-0607   CHN     19-0401-h     899     M      M
# 56364    1960-0607   CHN     19-0401-h     900     M      M
# 56365    1960-0607   CHN     19-0401-h     901     M      M
# 56366    1960-0607   CHN     19-0401-h     902     M      M
# 56367    1960-0607   CHN     19-0401-h     903     M      M
# 56368    1960-0607   CHN     19-0401-h     904     M      M
# 56369    1960-0607   CHN     19-0401-h     905     M      M
# 56370    1960-0607   CHN     19-0401-h     906     M      M
# 56371    1960-0607   CHN     19-0401-h     907     M      M
# 56372    1960-0607   CHN     19-0401-h     908     M      M
# 56616    1960-0607   CHN     19-0401-h    1152     M      M
# 56617    1960-0607   CHN     19-0401-h    1153     M      M
#
#                      c_created_at  count c_kind c_base a_role  u_name  \
# 15724  2019-06-11 09:12:28.088006      1      V      a     TE  dawnxu
# 15775  2019-06-15 03:25:11.855078      1      V      a     TE  dawnxu
# 30871  2018-01-06 19:20:40.907983      1      V      a     TE  estzhe
# 33361  2019-07-24 00:12:14.971666      1      V      a     TE  corche
# 34819  2020-05-13 03:47:44.384779      1      V      a     TE  dawnxu
# 35746  2020-02-01 06:08:24.434038      1      V      a     TE  dawnxu
# 42964  2019-05-31 07:05:46.896578      2      V      a     CE  marmwa
# 55587  2019-08-20 13:16:51.415398      1      V      a     TE  dawnxu
# 55749  2019-08-27 01:45:11.773081      1      V      a     TE  dawnxu
# 56098  2019-09-01 02:36:08.515518      1      V      a     TE  dawnxu
# 56326  2019-09-10 04:13:59.529688      1      V      a     TE  dawnxu
# 56361   2019-09-10 04:21:49.99019      1      V      a     TE  dawnxu
# 56362  2019-09-10 04:22:02.231998      1      V      a     TE  dawnxu
# 56363  2019-09-10 04:22:08.276047      1      V      a     TE  dawnxu
# 56364  2019-09-10 04:22:37.933537      1      V      a     TE  dawnxu
# 56365  2019-09-10 04:22:50.554829      1      V      a     TE  dawnxu
# 56366  2019-09-10 04:23:02.436897      1      V      a     TE  dawnxu
# 56367  2019-09-10 04:23:09.395605      1      V      a     TE  dawnxu
# 56368  2019-09-10 04:23:22.975408      1      V      a     TE  dawnxu
# 56369  2019-09-10 04:23:34.411307      1      V      a     TE  dawnxu
# 56370   2019-09-10 04:23:47.23145      1      V      a     TE  dawnxu
# 56371  2019-09-10 04:24:00.698148      1      V      a     TE  dawnxu
# 56372  2019-09-10 04:24:12.476136      1      V      a     TE  dawnxu
# 56616  2019-09-13 22:35:58.779078      1      V      a     TE  dawnxu
# 56617  2019-09-13 22:36:09.230981      1      V      a     TE  dawnxu
#
#       e_content
# 15724
# 15775
# 30871
# 33361
# 34819
# 35746
# 42964
# 55587
# 55749
# 56098
# 56326
# 56361
# 56362
# 56363
# 56364
# 56365
# 56366
# 56367
# 56368
# 56369
# 56370
# 56371
# 56372
# 56616
# 56617

# %%
# 
#add chars column
df_V['chars'] = [len(e) for e in df_V['e_content']] #TypeError: object of type 'float' has no len()
# df_V['chars'] = [len(e) if type(e)==str else 1 for e in df_V['e_content']]
df_V.loc[:5,['m_descriptor','t_lan','t_version','s_rsen','e_top','be_top','c_created_at','c_created_at_count','c_kind','c_base','a_role','chars']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-6f3669492967> in <module>()
#       3 df_V['chars'] = [len(e) for e in df_V['e_content']] #TypeError: object of type 'float' has no len()
#       4 # df_V['chars'] = [len(e) if type(e)==str else 1 for e in df_V['e_content']]
# ----> 5 df_V.loc[:5,['m_descriptor','t_lan','t_version','s_rsen','e_top','be_top','c_created_at','c_created_at_count','c_kind','c_base','a_role','chars']]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1053             return self._multi_take(tup)
#    1054
# -> 1055         return self._getitem_tuple_same_dim(tup)
#    1056
#    1057     def _get_label(self, label, axis: int):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     748                 continue
#     749
# --> 750             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     751             # We should never have retval.ndim < self.ndim, as that should
#     752             #  be handled by the _getitem_lowerdim call above.
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
# -> 1099                 return self._getitem_iterable(key, axis=axis)
#    1100
#    1101             # nested tuple slicing
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1035
#    1036         # A collection of keys
# -> 1037         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1038         return self.obj._reindex_with_indexers(
#    1039             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314                 with option_context("display.max_seq_items", 10, "display.width", 80):
#    1315                     raise KeyError(
# -> 1316                         "Passing list-likes to .loc or [] with any missing labels "
#    1317                         "is no longer supported. "
#    1318                         f"The following labels were missing: {not_found}. "
#
# KeyError: "Passing list-likes to .loc or [] with any missing labels is no longer supported. The following labels were missing: Index(['c_created_at_count'], dtype='object'). See https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike"

# %%
#hide
df_V

# %%
#hide 
# df_V.loc[e_content_nans, ['e_content','chars']]
# OR
df_V[df_V['chars']==0]

# %%
# 
#add words column
#https://www.geeksforgeeks.org/python-program-to-count-words-in-a-sentence/
df_V['words'] = [len(re.findall(r'\w+', e)) for e in df_V['e_content']]
df_V.loc[:5,['m_descriptor','t_lan','t_version','s_rsen','e_top','be_top','c_created_at','c_created_at_count','c_kind','c_base','a_role','chars','words']]

# %%
#hide
df_V

# %%
#hide 
# df_V[df_V['words']==0]

# %%
# 
#remove BER part from t_version; allows for joining to English contributions
df_V['t_version'] = ['-'.join(e.split('-')[:2]) for e in df_V['t_version']]
df_V.loc[:5,['m_descriptor','t_lan','t_version','s_rsen','e_top','be_top','c_created_at','c_created_at_count','c_kind','c_base','a_role','chars','words']]

# %%
#hide
df_V

# %% [markdown]
# # Merge E and V contributions

# %%
df_joind_EV = pd.merge(df_E, df_V, how='inner', on=['m_descriptor', 't_version', 's_rsen'], suffixes=('_E', '_V'), sort=True)
df_joind_EV.loc[:5,['m_descriptor','t_lan_E','t_version','s_rsen','c_id','chars_E','words_E','t_lan_V','e_top','be_top','c_created_at','c_created_at_count','c_kind','c_base','a_role','chars_V','words_V']]

# %%
#hide
df_joind_EV
# df_joined_EV[60000:70000]

# %% [markdown]
# # Save prepared data to file

# %%
df_joind_EV.to_csv (f'{PATH}/PredictTranslationWordAndCharCount/PredictTranslationWordAndCharCount_1-output.csv', sep='~', index = False, header=True)
